# %%
import time
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch

# %%
# Hyperparameters
RANDOM_SEED = 1
BATCH_SIZE = 100
NUM_EPOCHS = 100
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# Load dataswet
train_dataset = datasets.MNIST(
    root="data", train=True, transform=transforms.ToTensor(), download=True)

test_dataset = datasets.MNIST(root='data', 
                              train=False, 
                              transform=transforms.ToTensor())

train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Check the datasets
for images, labels in train_loader:
    print("Image batch dimensions: ", images.shape)
    print("Image label dimensions: ", labels.shape)
    break
# Out:
# Image batch dimensions:  torch.Size([100, 1, 28, 28])
# Image label dimensions:  torch.Size([100])

# %%
class MLP(torch.nn.Module):

    def __init__(self, num_features, num_hidden, num_classes):
        super().__init__()
        
        self.num_classes = num_classes
        
        ### 1st hidden layer
        self.linear_1 = torch.nn.Linear(num_features, num_hidden)

        ### Output layer
        self.linear_out = torch.nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        out = self.linear_1(x)
        out = torch.sigmoid(out)
        logits = self.linear_out(out)
        #probas = torch.softmax(logits, dim=1)
        return logits#, probas


# Model initialization
torch.manual_seed(RANDOM_SEED)

model = MLP(num_features=28*28, num_hidden=100, num_classes=10)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
# compute loss (helper function)
def compute_loss(net, data_loader):
    curr_loss = 0. 
    with torch.no_grad():
        for batch_num, (features, targets) in enumerate(data_loader):
            features = features.view(-1, 28*28).to(DEVICE)
            targets = targets.to(DEVICE)
            logits = net(features)
            loss = F.cross_entropy(logits, targets)
            curr_loss += loss
        return curr_loss/batch_num

# %%
# Train
start_time = time.time()
minibatch_cost = []
epoch_cost = []

for epoch in range(NUM_EPOCHS):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        features = features.view(-1, 28*28).to(DEVICE)
        targets = targets.to(DEVICE)
        
        # Model and backprop
        logit_preds = model(features)
        cost = F.cross_entropy(logit_preds, targets) 
        
        cost.backward() # compute gradient
        
        # Update weights
        optimizer.step()
        
        # Logging 
        minibatch_cost.append(cost.item())
        if not batch_idx % 50:
            print(f"Epoch : {epoch+1} | Batch {batch_idx}/{len(train_loader)} | Cost {cost.item():.3f}")
    
    # Compute train loss
    cost = compute_loss(model, train_loader)
    epoch_cost.append(cost)
    print(f"Epoch: {epoch + 1}/{NUM_EPOCHS} | Train cost: {cost:.2f}")
    print(f"Time elapsed: {(time.time() - start_time)/60}")
    
print(f"Total training time: {(time.time() - start_time)/60}")
# Out:
# Epoch : 1 | Batch 0/600 | Cost 2.337
# Epoch : 1 | Batch 50/600 | Cost 1.092
# Epoch : 1 | Batch 100/600 | Cost 0.329
# Epoch : 1 | Batch 150/600 | Cost 0.630
# Epoch : 1 | Batch 200/600 | Cost 1.015
# Epoch : 1 | Batch 250/600 | Cost 0.868
# Epoch : 1 | Batch 300/600 | Cost 0.348
# Epoch : 1 | Batch 350/600 | Cost 0.390
# Epoch : 1 | Batch 400/600 | Cost 0.464
# Epoch : 1 | Batch 450/600 | Cost 0.810
# Epoch : 1 | Batch 500/600 | Cost 0.994
# Epoch : 1 | Batch 550/600 | Cost 0.918
# Epoch: 1/100 | Train cost: 0.88
# Time elapsed: 0.17378560304641724
# Epoch : 2 | Batch 0/600 | Cost 0.864
# Epoch : 2 | Batch 50/600 | Cost 1.141
# Epoch : 2 | Batch 100/600 | Cost 1.400
# Epoch : 2 | Batch 150/600 | Cost 1.706
# Epoch : 2 | Batch 200/600 | Cost 0.982
# Epoch : 2 | Batch 250/600 | Cost 1.076
# Epoch : 2 | Batch 300/600 | Cost 0.983
# Epoch : 2 | Batch 350/600 | Cost 0.795
# Epoch : 2 | Batch 400/600 | Cost 0.681
# Epoch : 2 | Batch 450/600 | Cost 1.610
# Epoch : 2 | Batch 500/600 | Cost 2.001
# Epoch : 2 | Batch 550/600 | Cost 3.421
# Epoch: 2/100 | Train cost: 1.91
# Time elapsed: 0.3657148996988932
# Epoch : 3 | Batch 0/600 | Cost 1.832
# Epoch : 3 | Batch 50/600 | Cost 2.617
# Epoch : 3 | Batch 100/600 | Cost 2.697
# Epoch : 3 | Batch 150/600 | Cost 1.387
# Epoch : 3 | Batch 200/600 | Cost 2.709
# Epoch : 3 | Batch 250/600 | Cost 1.001
# Epoch : 3 | Batch 300/600 | Cost 1.617
# Epoch : 3 | Batch 350/600 | Cost 1.930
# Epoch : 3 | Batch 400/600 | Cost 2.468
# Epoch : 3 | Batch 450/600 | Cost 3.532
# Epoch : 3 | Batch 500/600 | Cost 3.142
# Epoch : 3 | Batch 550/600 | Cost 2.818
# Epoch: 3/100 | Train cost: 3.03
# Time elapsed: 0.5706639329592387
# Epoch : 4 | Batch 0/600 | Cost 4.360
# Epoch : 4 | Batch 50/600 | Cost 1.818
# Epoch : 4 | Batch 100/600 | Cost 1.918
# Epoch : 4 | Batch 150/600 | Cost 4.506
# Epoch : 4 | Batch 200/600 | Cost 3.122
# Epoch : 4 | Batch 250/600 | Cost 3.340
# Epoch : 4 | Batch 300/600 | Cost 2.216
# Epoch : 4 | Batch 350/600 | Cost 3.850
# Epoch : 4 | Batch 400/600 | Cost 3.113
# Epoch : 4 | Batch 450/600 | Cost 3.575
# Epoch : 4 | Batch 500/600 | Cost 2.976
# Epoch : 4 | Batch 550/600 | Cost 4.491
# Epoch: 4/100 | Train cost: 4.21
# Time elapsed: 0.7815464854240417
# Epoch : 5 | Batch 0/600 | Cost 3.617
# Epoch : 5 | Batch 50/600 | Cost 2.717
# Epoch : 5 | Batch 100/600 | Cost 5.882
# Epoch : 5 | Batch 150/600 | Cost 5.458
# Epoch : 5 | Batch 200/600 | Cost 6.169
# Epoch : 5 | Batch 250/600 | Cost 6.428
# Epoch : 5 | Batch 300/600 | Cost 4.372
# Epoch : 5 | Batch 350/600 | Cost 2.235
# Epoch : 5 | Batch 400/600 | Cost 5.207
# Epoch : 5 | Batch 450/600 | Cost 5.355
# Epoch : 5 | Batch 500/600 | Cost 4.629
# Epoch : 5 | Batch 550/600 | Cost 7.533
# Epoch: 5/100 | Train cost: 4.93
# Time elapsed: 1.0144832134246826
# Epoch : 6 | Batch 0/600 | Cost 4.464
# Epoch : 6 | Batch 50/600 | Cost 7.432
# Epoch : 6 | Batch 100/600 | Cost 4.874
# Epoch : 6 | Batch 150/600 | Cost 4.242
# Epoch : 6 | Batch 200/600 | Cost 6.632
# Epoch : 6 | Batch 250/600 | Cost 4.513
# Epoch : 6 | Batch 300/600 | Cost 2.913
# Epoch : 6 | Batch 350/600 | Cost 10.403
# Epoch : 6 | Batch 400/600 | Cost 8.530
# Epoch : 6 | Batch 450/600 | Cost 4.599
# Epoch : 6 | Batch 500/600 | Cost 5.889
# Epoch : 6 | Batch 550/600 | Cost 5.176
# Epoch: 6/100 | Train cost: 6.76
# Time elapsed: 1.2864780982335409
# Epoch : 7 | Batch 0/600 | Cost 9.663
# Epoch : 7 | Batch 50/600 | Cost 6.546
# Epoch : 7 | Batch 100/600 | Cost 7.579
# Epoch : 7 | Batch 150/600 | Cost 8.687
# Epoch : 7 | Batch 200/600 | Cost 6.314
# Epoch : 7 | Batch 250/600 | Cost 6.941
# Epoch : 7 | Batch 300/600 | Cost 4.765
# Epoch : 7 | Batch 350/600 | Cost 10.463
# Epoch : 7 | Batch 400/600 | Cost 12.803
# Epoch : 7 | Batch 450/600 | Cost 7.400
# Epoch : 7 | Batch 500/600 | Cost 7.056
# Epoch : 7 | Batch 550/600 | Cost 10.018
# Epoch: 7/100 | Train cost: 8.02
# Time elapsed: 1.5943182667096456
# Epoch : 8 | Batch 0/600 | Cost 5.898
# Epoch : 8 | Batch 50/600 | Cost 6.938
# Epoch : 8 | Batch 100/600 | Cost 11.853
# Epoch : 8 | Batch 150/600 | Cost 8.178
# Epoch : 8 | Batch 200/600 | Cost 8.578
# Epoch : 8 | Batch 250/600 | Cost 9.211
# Epoch : 8 | Batch 300/600 | Cost 8.662
# Epoch : 8 | Batch 350/600 | Cost 13.949
# Epoch : 8 | Batch 400/600 | Cost 7.726
# Epoch : 8 | Batch 450/600 | Cost 8.652
# Epoch : 8 | Batch 500/600 | Cost 11.826
# Epoch : 8 | Batch 550/600 | Cost 8.288
# Epoch: 8/100 | Train cost: 9.65
# Time elapsed: 1.962569034099579
# Epoch : 9 | Batch 0/600 | Cost 4.819
# Epoch : 9 | Batch 50/600 | Cost 14.213
# Epoch : 9 | Batch 100/600 | Cost 8.407
# Epoch : 9 | Batch 150/600 | Cost 11.842
# Epoch : 9 | Batch 200/600 | Cost 6.528
# Epoch : 9 | Batch 250/600 | Cost 11.046
# Epoch : 9 | Batch 300/600 | Cost 10.187
# Epoch : 9 | Batch 350/600 | Cost 6.015
# Epoch : 9 | Batch 400/600 | Cost 8.072
# Epoch : 9 | Batch 450/600 | Cost 6.563
# Epoch : 9 | Batch 500/600 | Cost 14.444
# Epoch : 9 | Batch 550/600 | Cost 10.391
# Epoch: 9/100 | Train cost: 9.48
# Time elapsed: 2.396818582216899
# Epoch : 10 | Batch 0/600 | Cost 9.798
# Epoch : 10 | Batch 50/600 | Cost 12.190
# Epoch : 10 | Batch 100/600 | Cost 6.803
# Epoch : 10 | Batch 150/600 | Cost 10.669
# Epoch : 10 | Batch 200/600 | Cost 10.072
# Epoch : 10 | Batch 250/600 | Cost 8.647
# Epoch : 10 | Batch 300/600 | Cost 15.299
# Epoch : 10 | Batch 350/600 | Cost 12.630
# Epoch : 10 | Batch 400/600 | Cost 6.773
# Epoch : 10 | Batch 450/600 | Cost 12.389
# Epoch : 10 | Batch 500/600 | Cost 9.142
# Epoch : 10 | Batch 550/600 | Cost 12.666
# Epoch: 10/100 | Train cost: 10.55
# Time elapsed: 2.90303320089976
# Epoch : 11 | Batch 0/600 | Cost 7.722
# Epoch : 11 | Batch 50/600 | Cost 10.533
# Epoch : 11 | Batch 100/600 | Cost 12.726
# Epoch : 11 | Batch 150/600 | Cost 11.366
# Epoch : 11 | Batch 200/600 | Cost 12.528
# Epoch : 11 | Batch 250/600 | Cost 11.689
# Epoch : 11 | Batch 300/600 | Cost 12.018
# Epoch : 11 | Batch 350/600 | Cost 9.897
# Epoch : 11 | Batch 400/600 | Cost 13.870
# Epoch : 11 | Batch 450/600 | Cost 7.938
# Epoch : 11 | Batch 500/600 | Cost 6.109
# Epoch : 11 | Batch 550/600 | Cost 9.457
# Epoch: 11/100 | Train cost: 9.71
# Time elapsed: 3.2934616684913633
# Epoch : 12 | Batch 0/600 | Cost 8.987
# Epoch : 12 | Batch 50/600 | Cost 8.410
# Epoch : 12 | Batch 100/600 | Cost 11.060
# Epoch : 12 | Batch 150/600 | Cost 12.758
# Epoch : 12 | Batch 200/600 | Cost 16.326
# Epoch : 12 | Batch 250/600 | Cost 11.105
# Epoch : 12 | Batch 300/600 | Cost 9.218
# Epoch : 12 | Batch 350/600 | Cost 7.228
# Epoch : 12 | Batch 400/600 | Cost 10.035
# Epoch : 12 | Batch 450/600 | Cost 13.049
# Epoch : 12 | Batch 500/600 | Cost 9.974
# Epoch : 12 | Batch 550/600 | Cost 12.305
# Epoch: 12/100 | Train cost: 10.93
# Time elapsed: 3.6643479824066163
# Epoch : 13 | Batch 0/600 | Cost 9.618
# Epoch : 13 | Batch 50/600 | Cost 8.636
# Epoch : 13 | Batch 100/600 | Cost 8.143
# Epoch : 13 | Batch 150/600 | Cost 6.386
# Epoch : 13 | Batch 200/600 | Cost 10.740
# Epoch : 13 | Batch 250/600 | Cost 8.728
# Epoch : 13 | Batch 300/600 | Cost 10.157
# Epoch : 13 | Batch 350/600 | Cost 8.888
# Epoch : 13 | Batch 400/600 | Cost 12.451
# Epoch : 13 | Batch 450/600 | Cost 10.143
# Epoch : 13 | Batch 500/600 | Cost 10.011
# Epoch : 13 | Batch 550/600 | Cost 11.824
# Epoch: 13/100 | Train cost: 12.28
# Time elapsed: 4.059057915210724
# Epoch : 14 | Batch 0/600 | Cost 11.172
# Epoch : 14 | Batch 50/600 | Cost 5.066
# Epoch : 14 | Batch 100/600 | Cost 10.466
# Epoch : 14 | Batch 150/600 | Cost 9.676
# Epoch : 14 | Batch 200/600 | Cost 13.827
# Epoch : 14 | Batch 250/600 | Cost 17.849
# Epoch : 14 | Batch 300/600 | Cost 9.673
# Epoch : 14 | Batch 350/600 | Cost 10.754
# Epoch : 14 | Batch 400/600 | Cost 13.050
# Epoch : 14 | Batch 450/600 | Cost 17.713
# Epoch : 14 | Batch 500/600 | Cost 14.539
# Epoch : 14 | Batch 550/600 | Cost 12.919
# Epoch: 14/100 | Train cost: 12.89
# Time elapsed: 4.464821668465932
# Epoch : 15 | Batch 0/600 | Cost 14.014
# Epoch : 15 | Batch 50/600 | Cost 12.286
# Epoch : 15 | Batch 100/600 | Cost 14.090
# Epoch : 15 | Batch 150/600 | Cost 12.206
# Epoch : 15 | Batch 200/600 | Cost 11.207
# Epoch : 15 | Batch 250/600 | Cost 20.729
# Epoch : 15 | Batch 300/600 | Cost 19.091
# Epoch : 15 | Batch 350/600 | Cost 8.104
# Epoch : 15 | Batch 400/600 | Cost 7.587
# Epoch : 15 | Batch 450/600 | Cost 15.028
# Epoch : 15 | Batch 500/600 | Cost 12.158
# Epoch : 15 | Batch 550/600 | Cost 8.393
# Epoch: 15/100 | Train cost: 12.84
# Time elapsed: 4.837110948562622
# Epoch : 16 | Batch 0/600 | Cost 9.881
# Epoch : 16 | Batch 50/600 | Cost 17.522
# Epoch : 16 | Batch 100/600 | Cost 12.853
# Epoch : 16 | Batch 150/600 | Cost 7.704
# Epoch : 16 | Batch 200/600 | Cost 12.891
# Epoch : 16 | Batch 250/600 | Cost 10.774
# Epoch : 16 | Batch 300/600 | Cost 12.980
# Epoch : 16 | Batch 350/600 | Cost 17.218
# Epoch : 16 | Batch 400/600 | Cost 23.100
# Epoch : 16 | Batch 450/600 | Cost 18.276
# Epoch : 16 | Batch 500/600 | Cost 12.348
# Epoch : 16 | Batch 550/600 | Cost 10.162
# Epoch: 16/100 | Train cost: 17.35
# Time elapsed: 5.191299982865652
# Epoch : 17 | Batch 0/600 | Cost 21.793
# Epoch : 17 | Batch 50/600 | Cost 20.199
# Epoch : 17 | Batch 100/600 | Cost 20.616
# Epoch : 17 | Batch 150/600 | Cost 28.320
# Epoch : 17 | Batch 200/600 | Cost 11.327
# Epoch : 17 | Batch 250/600 | Cost 12.373
# Epoch : 17 | Batch 300/600 | Cost 17.981
# Epoch : 17 | Batch 350/600 | Cost 13.170
# Epoch : 17 | Batch 400/600 | Cost 8.378
# Epoch : 17 | Batch 450/600 | Cost 17.636
# Epoch : 17 | Batch 500/600 | Cost 19.033
# Epoch : 17 | Batch 550/600 | Cost 19.149
# Epoch: 17/100 | Train cost: 15.58
# Time elapsed: 5.545644847551982
# Epoch : 18 | Batch 0/600 | Cost 11.473
# Epoch : 18 | Batch 50/600 | Cost 19.076
# Epoch : 18 | Batch 100/600 | Cost 15.954
# Epoch : 18 | Batch 150/600 | Cost 17.491
# Epoch : 18 | Batch 200/600 | Cost 17.379
# Epoch : 18 | Batch 250/600 | Cost 29.727
# Epoch : 18 | Batch 300/600 | Cost 20.727
# Epoch : 18 | Batch 350/600 | Cost 20.970
# Epoch : 18 | Batch 400/600 | Cost 20.048
# Epoch : 18 | Batch 450/600 | Cost 21.507
# Epoch : 18 | Batch 500/600 | Cost 21.161
# Epoch : 18 | Batch 550/600 | Cost 19.207
# Epoch: 18/100 | Train cost: 17.68
# Time elapsed: 5.877410248915354
# Epoch : 19 | Batch 0/600 | Cost 16.425
# Epoch : 19 | Batch 50/600 | Cost 16.628
# Epoch : 19 | Batch 100/600 | Cost 14.663
# Epoch : 19 | Batch 150/600 | Cost 17.925
# Epoch : 19 | Batch 200/600 | Cost 24.961
# Epoch : 19 | Batch 250/600 | Cost 24.216
# Epoch : 19 | Batch 300/600 | Cost 23.777
# Epoch : 19 | Batch 350/600 | Cost 38.907
# Epoch : 19 | Batch 400/600 | Cost 28.928
# Epoch : 19 | Batch 450/600 | Cost 22.566
# Epoch : 19 | Batch 500/600 | Cost 27.503
# Epoch : 19 | Batch 550/600 | Cost 16.848
# Epoch: 19/100 | Train cost: 17.04
# Time elapsed: 6.193410217761993
# Epoch : 20 | Batch 0/600 | Cost 9.756
# Epoch : 20 | Batch 50/600 | Cost 12.157
# Epoch : 20 | Batch 100/600 | Cost 12.008
# Epoch : 20 | Batch 150/600 | Cost 22.663
# Epoch : 20 | Batch 200/600 | Cost 38.814
# Epoch : 20 | Batch 250/600 | Cost 13.026
# Epoch : 20 | Batch 300/600 | Cost 10.868
# Epoch : 20 | Batch 350/600 | Cost 23.275
# Epoch : 20 | Batch 400/600 | Cost 16.633
# Epoch : 20 | Batch 450/600 | Cost 23.633
# Epoch : 20 | Batch 500/600 | Cost 19.799
# Epoch : 20 | Batch 550/600 | Cost 23.290
# Epoch: 20/100 | Train cost: 16.95
# Time elapsed: 6.510402584075928
# Epoch : 21 | Batch 0/600 | Cost 14.195
# Epoch : 21 | Batch 50/600 | Cost 14.729
# Epoch : 21 | Batch 100/600 | Cost 10.181
# Epoch : 21 | Batch 150/600 | Cost 15.424
# Epoch : 21 | Batch 200/600 | Cost 11.248
# Epoch : 21 | Batch 250/600 | Cost 10.531
# Epoch : 21 | Batch 300/600 | Cost 22.782
# Epoch : 21 | Batch 350/600 | Cost 27.298
# Epoch : 21 | Batch 400/600 | Cost 13.033
# Epoch : 21 | Batch 450/600 | Cost 29.218
# Epoch : 21 | Batch 500/600 | Cost 40.813
# Epoch : 21 | Batch 550/600 | Cost 12.039
# Epoch: 21/100 | Train cost: 18.96
# Time elapsed: 6.910774401823679
# Epoch : 22 | Batch 0/600 | Cost 22.639
# Epoch : 22 | Batch 50/600 | Cost 21.428
# Epoch : 22 | Batch 100/600 | Cost 9.414
# Epoch : 22 | Batch 150/600 | Cost 23.472
# Epoch : 22 | Batch 200/600 | Cost 24.484
# Epoch : 22 | Batch 250/600 | Cost 9.356
# Epoch : 22 | Batch 300/600 | Cost 13.230
# Epoch : 22 | Batch 350/600 | Cost 17.154
# Epoch : 22 | Batch 400/600 | Cost 21.221
# Epoch : 22 | Batch 450/600 | Cost 16.602
# Epoch : 22 | Batch 500/600 | Cost 20.768
# Epoch : 22 | Batch 550/600 | Cost 16.658
# Epoch: 22/100 | Train cost: 17.76
# Time elapsed: 7.380894283453624
# Epoch : 23 | Batch 0/600 | Cost 22.635
# Epoch : 23 | Batch 50/600 | Cost 27.839
# Epoch : 23 | Batch 100/600 | Cost 11.857
# Epoch : 23 | Batch 150/600 | Cost 19.480
# Epoch : 23 | Batch 200/600 | Cost 18.435
# Epoch : 23 | Batch 250/600 | Cost 42.130
# Epoch : 23 | Batch 300/600 | Cost 14.511
# Epoch : 23 | Batch 350/600 | Cost 25.839
# Epoch : 23 | Batch 400/600 | Cost 21.479
# Epoch : 23 | Batch 450/600 | Cost 23.873
# Epoch : 23 | Batch 500/600 | Cost 16.631
# Epoch : 23 | Batch 550/600 | Cost 27.316
# Epoch: 23/100 | Train cost: 17.34
# Time elapsed: 7.784253784020742
# Epoch : 24 | Batch 0/600 | Cost 13.678
# Epoch : 24 | Batch 50/600 | Cost 22.477
# Epoch : 24 | Batch 100/600 | Cost 25.094
# Epoch : 24 | Batch 150/600 | Cost 10.201
# Epoch : 24 | Batch 200/600 | Cost 19.178
# Epoch : 24 | Batch 250/600 | Cost 22.292
# Epoch : 24 | Batch 300/600 | Cost 24.910
# Epoch : 24 | Batch 350/600 | Cost 31.896
# Epoch : 24 | Batch 400/600 | Cost 21.814
# Epoch : 24 | Batch 450/600 | Cost 9.494
# Epoch : 24 | Batch 500/600 | Cost 17.547
# Epoch : 24 | Batch 550/600 | Cost 21.726
# Epoch: 24/100 | Train cost: 19.30
# Time elapsed: 8.115728783607484
# Epoch : 25 | Batch 0/600 | Cost 9.297
# Epoch : 25 | Batch 50/600 | Cost 9.070
# Epoch : 25 | Batch 100/600 | Cost 32.497
# Epoch : 25 | Batch 150/600 | Cost 19.729
# Epoch : 25 | Batch 200/600 | Cost 24.842
# Epoch : 25 | Batch 250/600 | Cost 19.586
# Epoch : 25 | Batch 300/600 | Cost 48.783
# Epoch : 25 | Batch 350/600 | Cost 16.738
# Epoch : 25 | Batch 400/600 | Cost 10.511
# Epoch : 25 | Batch 450/600 | Cost 12.759
# Epoch : 25 | Batch 500/600 | Cost 21.195
# Epoch : 25 | Batch 550/600 | Cost 12.934
# Epoch: 25/100 | Train cost: 19.02
# Time elapsed: 8.429026516278585
# Epoch : 26 | Batch 0/600 | Cost 12.432
# Epoch : 26 | Batch 50/600 | Cost 11.170
# Epoch : 26 | Batch 100/600 | Cost 19.152
# Epoch : 26 | Batch 150/600 | Cost 11.326
# Epoch : 26 | Batch 200/600 | Cost 19.792
# Epoch : 26 | Batch 250/600 | Cost 21.256
# Epoch : 26 | Batch 300/600 | Cost 21.452
# Epoch : 26 | Batch 350/600 | Cost 8.942
# Epoch : 26 | Batch 400/600 | Cost 15.492
# Epoch : 26 | Batch 450/600 | Cost 10.877
# Epoch : 26 | Batch 500/600 | Cost 18.458
# Epoch : 26 | Batch 550/600 | Cost 12.137
# Epoch: 26/100 | Train cost: 20.03
# Time elapsed: 8.744827902317047
# Epoch : 27 | Batch 0/600 | Cost 35.659
# Epoch : 27 | Batch 50/600 | Cost 15.293
# Epoch : 27 | Batch 100/600 | Cost 18.614
# Epoch : 27 | Batch 150/600 | Cost 17.366
# Epoch : 27 | Batch 200/600 | Cost 26.338
# Epoch : 27 | Batch 250/600 | Cost 19.095
# Epoch : 27 | Batch 300/600 | Cost 13.235
# Epoch : 27 | Batch 350/600 | Cost 20.848
# Epoch : 27 | Batch 400/600 | Cost 24.195
# Epoch : 27 | Batch 450/600 | Cost 26.880
# Epoch : 27 | Batch 500/600 | Cost 20.583
# Epoch : 27 | Batch 550/600 | Cost 22.880
# Epoch: 27/100 | Train cost: 18.86
# Time elapsed: 9.137140130996704
# Epoch : 28 | Batch 0/600 | Cost 14.619
# Epoch : 28 | Batch 50/600 | Cost 27.705
# Epoch : 28 | Batch 100/600 | Cost 22.247
# Epoch : 28 | Batch 150/600 | Cost 20.478
# Epoch : 28 | Batch 200/600 | Cost 24.866
# Epoch : 28 | Batch 250/600 | Cost 29.280
# Epoch : 28 | Batch 300/600 | Cost 15.669
# Epoch : 28 | Batch 350/600 | Cost 21.067
# Epoch : 28 | Batch 400/600 | Cost 22.593
# Epoch : 28 | Batch 450/600 | Cost 25.611
# Epoch : 28 | Batch 500/600 | Cost 21.651
# Epoch : 28 | Batch 550/600 | Cost 24.269
# Epoch: 28/100 | Train cost: 17.97
# Time elapsed: 9.513391252358755
# Epoch : 29 | Batch 0/600 | Cost 12.268
# Epoch : 29 | Batch 50/600 | Cost 24.905
# Epoch : 29 | Batch 100/600 | Cost 19.060
# Epoch : 29 | Batch 150/600 | Cost 25.473
# Epoch : 29 | Batch 200/600 | Cost 22.775
# Epoch : 29 | Batch 250/600 | Cost 34.534
# Epoch : 29 | Batch 300/600 | Cost 18.063
# Epoch : 29 | Batch 350/600 | Cost 30.642
# Epoch : 29 | Batch 400/600 | Cost 26.851
# Epoch : 29 | Batch 450/600 | Cost 15.624
# Epoch : 29 | Batch 500/600 | Cost 14.489
# Epoch : 29 | Batch 550/600 | Cost 25.134
# Epoch: 29/100 | Train cost: 28.78
# Time elapsed: 9.965470782915752
# Epoch : 30 | Batch 0/600 | Cost 26.308
# Epoch : 30 | Batch 50/600 | Cost 35.523
# Epoch : 30 | Batch 100/600 | Cost 22.592
# Epoch : 30 | Batch 150/600 | Cost 41.393
# Epoch : 30 | Batch 200/600 | Cost 27.193
# Epoch : 30 | Batch 250/600 | Cost 31.961
# Epoch : 30 | Batch 300/600 | Cost 19.059
# Epoch : 30 | Batch 350/600 | Cost 28.489
# Epoch : 30 | Batch 400/600 | Cost 23.725
# Epoch : 30 | Batch 450/600 | Cost 22.162
# Epoch : 30 | Batch 500/600 | Cost 34.965
# Epoch : 30 | Batch 550/600 | Cost 29.659
# Epoch: 30/100 | Train cost: 34.80
# Time elapsed: 10.921675598621368
# Epoch : 31 | Batch 0/600 | Cost 29.130
# Epoch : 31 | Batch 50/600 | Cost 34.930
# Epoch : 31 | Batch 100/600 | Cost 42.737
# Epoch : 31 | Batch 150/600 | Cost 16.652
# Epoch : 31 | Batch 200/600 | Cost 19.239
# Epoch : 31 | Batch 250/600 | Cost 30.422
# Epoch : 31 | Batch 300/600 | Cost 14.327
# Epoch : 31 | Batch 350/600 | Cost 24.139
# Epoch : 31 | Batch 400/600 | Cost 14.954
# Epoch : 31 | Batch 450/600 | Cost 29.336
# Epoch : 31 | Batch 500/600 | Cost 30.363
# Epoch : 31 | Batch 550/600 | Cost 26.050
# Epoch: 31/100 | Train cost: 38.54
# Time elapsed: 11.727215099334718
# Epoch : 32 | Batch 0/600 | Cost 32.770
# Epoch : 32 | Batch 50/600 | Cost 36.212
# Epoch : 32 | Batch 100/600 | Cost 25.858
# Epoch : 32 | Batch 150/600 | Cost 43.920
# Epoch : 32 | Batch 200/600 | Cost 24.789
# Epoch : 32 | Batch 250/600 | Cost 21.797
# Epoch : 32 | Batch 300/600 | Cost 27.033
# Epoch : 32 | Batch 350/600 | Cost 40.254
# Epoch : 32 | Batch 400/600 | Cost 23.711
# Epoch : 32 | Batch 450/600 | Cost 28.235
# Epoch : 32 | Batch 500/600 | Cost 59.674
# Epoch : 32 | Batch 550/600 | Cost 40.344
# Epoch: 32/100 | Train cost: 35.85
# Time elapsed: 12.263927082220713
# Epoch : 33 | Batch 0/600 | Cost 32.429
# Epoch : 33 | Batch 50/600 | Cost 28.440
# Epoch : 33 | Batch 100/600 | Cost 40.117
# Epoch : 33 | Batch 150/600 | Cost 28.703
# Epoch : 33 | Batch 200/600 | Cost 42.501
# Epoch : 33 | Batch 250/600 | Cost 25.634
# Epoch : 33 | Batch 300/600 | Cost 28.240
# Epoch : 33 | Batch 350/600 | Cost 40.980
# Epoch : 33 | Batch 400/600 | Cost 18.948
# Epoch : 33 | Batch 450/600 | Cost 32.252
# Epoch : 33 | Batch 500/600 | Cost 32.116
# Epoch : 33 | Batch 550/600 | Cost 38.675
# Epoch: 33/100 | Train cost: 39.80
# Time elapsed: 12.797655316193898
# Epoch : 34 | Batch 0/600 | Cost 39.557
# Epoch : 34 | Batch 50/600 | Cost 37.939
# Epoch : 34 | Batch 100/600 | Cost 12.160
# Epoch : 34 | Batch 150/600 | Cost 49.901
# Epoch : 34 | Batch 200/600 | Cost 54.396
# Epoch : 34 | Batch 250/600 | Cost 45.658
# Epoch : 34 | Batch 300/600 | Cost 49.922
# Epoch : 34 | Batch 350/600 | Cost 42.661
# Epoch : 34 | Batch 400/600 | Cost 25.515
# Epoch : 34 | Batch 450/600 | Cost 34.280
# Epoch : 34 | Batch 500/600 | Cost 64.127
# Epoch : 34 | Batch 550/600 | Cost 45.107
# Epoch: 34/100 | Train cost: 40.61
# Time elapsed: 13.550614134470623
# Epoch : 35 | Batch 0/600 | Cost 44.638
# Epoch : 35 | Batch 50/600 | Cost 34.461
# Epoch : 35 | Batch 100/600 | Cost 80.667
# Epoch : 35 | Batch 150/600 | Cost 30.504
# Epoch : 35 | Batch 200/600 | Cost 18.363
# Epoch : 35 | Batch 250/600 | Cost 48.914
# Epoch : 35 | Batch 300/600 | Cost 42.306
# Epoch : 35 | Batch 350/600 | Cost 27.857
# Epoch : 35 | Batch 400/600 | Cost 53.488
# Epoch : 35 | Batch 450/600 | Cost 55.544
# Epoch : 35 | Batch 500/600 | Cost 46.002
# Epoch : 35 | Batch 550/600 | Cost 44.442
# Epoch: 35/100 | Train cost: 44.00
# Time elapsed: 14.50916529893875
# Epoch : 36 | Batch 0/600 | Cost 50.802
# Epoch : 36 | Batch 50/600 | Cost 31.691
# Epoch : 36 | Batch 100/600 | Cost 32.022
# Epoch : 36 | Batch 150/600 | Cost 44.043
# Epoch : 36 | Batch 200/600 | Cost 66.524
# Epoch : 36 | Batch 250/600 | Cost 29.529
# Epoch : 36 | Batch 300/600 | Cost 32.868
# Epoch : 36 | Batch 350/600 | Cost 50.846
# Epoch : 36 | Batch 400/600 | Cost 50.729
# Epoch : 36 | Batch 450/600 | Cost 23.063
# Epoch : 36 | Batch 500/600 | Cost 36.245
# Epoch : 36 | Batch 550/600 | Cost 31.143
# Epoch: 36/100 | Train cost: 30.70
# Time elapsed: 15.300007164478302
# Epoch : 37 | Batch 0/600 | Cost 21.680
# Epoch : 37 | Batch 50/600 | Cost 64.987
# Epoch : 37 | Batch 100/600 | Cost 31.841
# Epoch : 37 | Batch 150/600 | Cost 71.010
# Epoch : 37 | Batch 200/600 | Cost 16.253
# Epoch : 37 | Batch 250/600 | Cost 33.058
# Epoch : 37 | Batch 300/600 | Cost 48.421
# Epoch : 37 | Batch 350/600 | Cost 62.732
# Epoch : 37 | Batch 400/600 | Cost 43.004
# Epoch : 37 | Batch 450/600 | Cost 29.018
# Epoch : 37 | Batch 500/600 | Cost 30.288
# Epoch : 37 | Batch 550/600 | Cost 50.779
# Epoch: 37/100 | Train cost: 37.04
# Time elapsed: 15.81937471628189
# Epoch : 38 | Batch 0/600 | Cost 27.610
# Epoch : 38 | Batch 50/600 | Cost 40.881
# Epoch : 38 | Batch 100/600 | Cost 58.261
# Epoch : 38 | Batch 150/600 | Cost 20.496
# Epoch : 38 | Batch 200/600 | Cost 22.667
# Epoch : 38 | Batch 250/600 | Cost 26.950
# Epoch : 38 | Batch 300/600 | Cost 51.729
# Epoch : 38 | Batch 350/600 | Cost 43.592
# Epoch : 38 | Batch 400/600 | Cost 24.679
# Epoch : 38 | Batch 450/600 | Cost 25.168
# Epoch : 38 | Batch 500/600 | Cost 40.935
# Epoch : 38 | Batch 550/600 | Cost 65.828
# Epoch: 38/100 | Train cost: 42.23
# Time elapsed: 16.3075471162796
# Epoch : 39 | Batch 0/600 | Cost 34.756
# Epoch : 39 | Batch 50/600 | Cost 30.023
# Epoch : 39 | Batch 100/600 | Cost 55.485
# Epoch : 39 | Batch 150/600 | Cost 27.843
# Epoch : 39 | Batch 200/600 | Cost 48.328
# Epoch : 39 | Batch 250/600 | Cost 47.808
# Epoch : 39 | Batch 300/600 | Cost 29.473
# Epoch : 39 | Batch 350/600 | Cost 20.251
# Epoch : 39 | Batch 400/600 | Cost 31.663
# Epoch : 39 | Batch 450/600 | Cost 64.278
# Epoch : 39 | Batch 500/600 | Cost 28.236
# Epoch : 39 | Batch 550/600 | Cost 41.532
# Epoch: 39/100 | Train cost: 53.78
# Time elapsed: 16.879492831230163
# Epoch : 40 | Batch 0/600 | Cost 32.181
# Epoch : 40 | Batch 50/600 | Cost 21.935
# Epoch : 40 | Batch 100/600 | Cost 30.572
# Epoch : 40 | Batch 150/600 | Cost 71.878
# Epoch : 40 | Batch 200/600 | Cost 25.875
# Epoch : 40 | Batch 250/600 | Cost 58.483
# Epoch : 40 | Batch 300/600 | Cost 61.562
# Epoch : 40 | Batch 350/600 | Cost 75.575
# Epoch : 40 | Batch 400/600 | Cost 62.983
# Epoch : 40 | Batch 450/600 | Cost 72.536
# Epoch : 40 | Batch 500/600 | Cost 51.566
# Epoch : 40 | Batch 550/600 | Cost 58.589
# Epoch: 40/100 | Train cost: 77.16
# Time elapsed: 17.787775146961213
# Epoch : 41 | Batch 0/600 | Cost 128.930
# Epoch : 41 | Batch 50/600 | Cost 56.380
# Epoch : 41 | Batch 100/600 | Cost 40.631
# Epoch : 41 | Batch 150/600 | Cost 131.225
# Epoch : 41 | Batch 200/600 | Cost 58.836
# Epoch : 41 | Batch 250/600 | Cost 39.262
# Epoch : 41 | Batch 300/600 | Cost 50.732
# Epoch : 41 | Batch 350/600 | Cost 101.493
# Epoch : 41 | Batch 400/600 | Cost 77.579
# Epoch : 41 | Batch 450/600 | Cost 114.136
# Epoch : 41 | Batch 500/600 | Cost 85.127
# Epoch : 41 | Batch 550/600 | Cost 89.858
# Epoch: 41/100 | Train cost: 68.59
# Time elapsed: 18.662780165672302
# Epoch : 42 | Batch 0/600 | Cost 61.296
# Epoch : 42 | Batch 50/600 | Cost 47.675
# Epoch : 42 | Batch 100/600 | Cost 76.238
# Epoch : 42 | Batch 150/600 | Cost 121.025
# Epoch : 42 | Batch 200/600 | Cost 51.295
# Epoch : 42 | Batch 250/600 | Cost 39.054
# Epoch : 42 | Batch 300/600 | Cost 67.013
# Epoch : 42 | Batch 350/600 | Cost 35.443
# Epoch : 42 | Batch 400/600 | Cost 34.083
# Epoch : 42 | Batch 450/600 | Cost 41.073
# Epoch : 42 | Batch 500/600 | Cost 49.315
# Epoch : 42 | Batch 550/600 | Cost 58.541
# Epoch: 42/100 | Train cost: 56.97
# Time elapsed: 19.29006569782893
# Epoch : 43 | Batch 0/600 | Cost 73.668
# Epoch : 43 | Batch 50/600 | Cost 62.642
# Epoch : 43 | Batch 100/600 | Cost 57.698
# Epoch : 43 | Batch 150/600 | Cost 85.188
# Epoch : 43 | Batch 200/600 | Cost 83.643
# Epoch : 43 | Batch 250/600 | Cost 60.010
# Epoch : 43 | Batch 300/600 | Cost 45.465
# Epoch : 43 | Batch 350/600 | Cost 56.040
# Epoch : 43 | Batch 400/600 | Cost 29.395
# Epoch : 43 | Batch 450/600 | Cost 45.153
# Epoch : 43 | Batch 500/600 | Cost 45.423
# Epoch : 43 | Batch 550/600 | Cost 48.813
# Epoch: 43/100 | Train cost: 48.49
# Time elapsed: 19.91836449702581
# Epoch : 44 | Batch 0/600 | Cost 42.484
# Epoch : 44 | Batch 50/600 | Cost 53.655
# Epoch : 44 | Batch 100/600 | Cost 40.085
# Epoch : 44 | Batch 150/600 | Cost 64.382
# Epoch : 44 | Batch 200/600 | Cost 48.818
# Epoch : 44 | Batch 250/600 | Cost 46.223
# Epoch : 44 | Batch 300/600 | Cost 54.382
# Epoch : 44 | Batch 350/600 | Cost 42.176
# Epoch : 44 | Batch 400/600 | Cost 59.840
# Epoch : 44 | Batch 450/600 | Cost 51.704
# Epoch : 44 | Batch 500/600 | Cost 44.168
# Epoch : 44 | Batch 550/600 | Cost 65.447
# Epoch: 44/100 | Train cost: 51.68
# Time elapsed: 20.550642267862955
# Epoch : 45 | Batch 0/600 | Cost 61.371
# Epoch : 45 | Batch 50/600 | Cost 51.638
# Epoch : 45 | Batch 100/600 | Cost 42.735
# Epoch : 45 | Batch 150/600 | Cost 56.726
# Epoch : 45 | Batch 200/600 | Cost 44.487
# Epoch : 45 | Batch 250/600 | Cost 46.477
# Epoch : 45 | Batch 300/600 | Cost 75.047
# Epoch : 45 | Batch 350/600 | Cost 27.778
# Epoch : 45 | Batch 400/600 | Cost 32.206
# Epoch : 45 | Batch 450/600 | Cost 49.192
# Epoch : 45 | Batch 500/600 | Cost 43.313
# Epoch : 45 | Batch 550/600 | Cost 48.069
# Epoch: 45/100 | Train cost: 60.20
# Time elapsed: 21.20734393199285
# Epoch : 46 | Batch 0/600 | Cost 51.579
# Epoch : 46 | Batch 50/600 | Cost 43.772
# Epoch : 46 | Batch 100/600 | Cost 48.032
# Epoch : 46 | Batch 150/600 | Cost 38.358
# Epoch : 46 | Batch 200/600 | Cost 78.879
# Epoch : 46 | Batch 250/600 | Cost 65.236
# Epoch : 46 | Batch 300/600 | Cost 70.345
# Epoch : 46 | Batch 350/600 | Cost 43.781
# Epoch : 46 | Batch 400/600 | Cost 44.337
# Epoch : 46 | Batch 450/600 | Cost 35.145
# Epoch : 46 | Batch 500/600 | Cost 78.587
# Epoch : 46 | Batch 550/600 | Cost 53.592
# Epoch: 46/100 | Train cost: 50.19
# Time elapsed: 21.929265081882477
# Epoch : 47 | Batch 0/600 | Cost 55.207
# Epoch : 47 | Batch 50/600 | Cost 83.279
# Epoch : 47 | Batch 100/600 | Cost 63.904
# Epoch : 47 | Batch 150/600 | Cost 38.071
# Epoch : 47 | Batch 200/600 | Cost 46.638
# Epoch : 47 | Batch 250/600 | Cost 46.416
# Epoch : 47 | Batch 300/600 | Cost 63.672
# Epoch : 47 | Batch 350/600 | Cost 46.860
# Epoch : 47 | Batch 400/600 | Cost 50.513
# Epoch : 47 | Batch 450/600 | Cost 61.900
# Epoch : 47 | Batch 500/600 | Cost 49.116
# Epoch : 47 | Batch 550/600 | Cost 90.873
# Epoch: 47/100 | Train cost: 53.60
# Time elapsed: 22.722781483332316
# Epoch : 48 | Batch 0/600 | Cost 55.265
# Epoch : 48 | Batch 50/600 | Cost 60.525
# Epoch : 48 | Batch 100/600 | Cost 53.016
# Epoch : 48 | Batch 150/600 | Cost 32.348
# Epoch : 48 | Batch 200/600 | Cost 59.738
# Epoch : 48 | Batch 250/600 | Cost 52.322
# Epoch : 48 | Batch 300/600 | Cost 56.532
# Epoch : 48 | Batch 350/600 | Cost 54.262
# Epoch : 48 | Batch 400/600 | Cost 40.902
# Epoch : 48 | Batch 450/600 | Cost 54.912
# Epoch : 48 | Batch 500/600 | Cost 55.642
# Epoch : 48 | Batch 550/600 | Cost 47.004
# Epoch: 48/100 | Train cost: 42.76
# Time elapsed: 23.52191143433253
# Epoch : 49 | Batch 0/600 | Cost 34.867
# Epoch : 49 | Batch 50/600 | Cost 29.717
# Epoch : 49 | Batch 100/600 | Cost 47.560
# Epoch : 49 | Batch 150/600 | Cost 38.836
# Epoch : 49 | Batch 200/600 | Cost 48.056
# Epoch : 49 | Batch 250/600 | Cost 41.613
# Epoch : 49 | Batch 300/600 | Cost 55.048
# Epoch : 49 | Batch 350/600 | Cost 26.586
# Epoch : 49 | Batch 400/600 | Cost 51.565
# Epoch : 49 | Batch 450/600 | Cost 52.159
# Epoch : 49 | Batch 500/600 | Cost 49.521
# Epoch : 49 | Batch 550/600 | Cost 22.044
# Epoch: 49/100 | Train cost: 44.50
# Time elapsed: 24.30978424946467
# Epoch : 50 | Batch 0/600 | Cost 38.183
# Epoch : 50 | Batch 50/600 | Cost 44.145
# Epoch : 50 | Batch 100/600 | Cost 31.008
# Epoch : 50 | Batch 150/600 | Cost 49.054
# Epoch : 50 | Batch 200/600 | Cost 33.889
# Epoch : 50 | Batch 250/600 | Cost 57.725
# Epoch : 50 | Batch 300/600 | Cost 43.056
# Epoch : 50 | Batch 350/600 | Cost 47.560
# Epoch : 50 | Batch 400/600 | Cost 51.057
# Epoch : 50 | Batch 450/600 | Cost 35.470
# Epoch : 50 | Batch 500/600 | Cost 76.926
# Epoch : 50 | Batch 550/600 | Cost 78.374
# Epoch: 50/100 | Train cost: 50.50
# Time elapsed: 24.916145447889964
# Epoch : 51 | Batch 0/600 | Cost 36.642
# Epoch : 51 | Batch 50/600 | Cost 26.079
# Epoch : 51 | Batch 100/600 | Cost 56.657
# Epoch : 51 | Batch 150/600 | Cost 66.644
# Epoch : 51 | Batch 200/600 | Cost 41.543
# Epoch : 51 | Batch 250/600 | Cost 72.023
# Epoch : 51 | Batch 300/600 | Cost 46.906
# Epoch : 51 | Batch 350/600 | Cost 80.909
# Epoch : 51 | Batch 400/600 | Cost 46.989
# Epoch : 51 | Batch 450/600 | Cost 59.521
# Epoch : 51 | Batch 500/600 | Cost 71.906
# Epoch : 51 | Batch 550/600 | Cost 61.249
# Epoch: 51/100 | Train cost: 60.82
# Time elapsed: 25.50074812968572
# Epoch : 52 | Batch 0/600 | Cost 46.930
# Epoch : 52 | Batch 50/600 | Cost 50.476
# Epoch : 52 | Batch 100/600 | Cost 78.919
# Epoch : 52 | Batch 150/600 | Cost 75.362
# Epoch : 52 | Batch 200/600 | Cost 64.077
# Epoch : 52 | Batch 250/600 | Cost 81.154
# Epoch : 52 | Batch 300/600 | Cost 58.015
# Epoch : 52 | Batch 350/600 | Cost 32.212
# Epoch : 52 | Batch 400/600 | Cost 92.852
# Epoch : 52 | Batch 450/600 | Cost 45.404
# Epoch : 52 | Batch 500/600 | Cost 59.209
# Epoch : 52 | Batch 550/600 | Cost 34.654
# Epoch: 52/100 | Train cost: 60.72
# Time elapsed: 26.100506313641866
# Epoch : 53 | Batch 0/600 | Cost 61.972
# Epoch : 53 | Batch 50/600 | Cost 67.910
# Epoch : 53 | Batch 100/600 | Cost 66.833
# Epoch : 53 | Batch 150/600 | Cost 53.015
# Epoch : 53 | Batch 200/600 | Cost 45.039
# Epoch : 53 | Batch 250/600 | Cost 96.104
# Epoch : 53 | Batch 300/600 | Cost 47.263
# Epoch : 53 | Batch 350/600 | Cost 31.108
# Epoch : 53 | Batch 400/600 | Cost 32.199
# Epoch : 53 | Batch 450/600 | Cost 91.575
# Epoch : 53 | Batch 500/600 | Cost 61.760
# Epoch : 53 | Batch 550/600 | Cost 48.068
# Epoch: 53/100 | Train cost: 45.57
# Time elapsed: 27.166125416755676
# Epoch : 54 | Batch 0/600 | Cost 42.909
# Epoch : 54 | Batch 50/600 | Cost 42.736
# Epoch : 54 | Batch 100/600 | Cost 41.336
# Epoch : 54 | Batch 150/600 | Cost 50.619
# Epoch : 54 | Batch 200/600 | Cost 60.699
# Epoch : 54 | Batch 250/600 | Cost 64.710
# Epoch : 54 | Batch 300/600 | Cost 37.293
# Epoch : 54 | Batch 350/600 | Cost 62.815
# Epoch : 54 | Batch 400/600 | Cost 33.067
# Epoch : 54 | Batch 450/600 | Cost 70.509
# Epoch : 54 | Batch 500/600 | Cost 38.868
# Epoch : 54 | Batch 550/600 | Cost 65.165
# Epoch: 54/100 | Train cost: 49.95
# Time elapsed: 28.07481753428777
# Epoch : 55 | Batch 0/600 | Cost 50.473
# Epoch : 55 | Batch 50/600 | Cost 58.018
# Epoch : 55 | Batch 100/600 | Cost 56.916
# Epoch : 55 | Batch 150/600 | Cost 61.044
# Epoch : 55 | Batch 200/600 | Cost 73.078
# Epoch : 55 | Batch 250/600 | Cost 62.138
# Epoch : 55 | Batch 300/600 | Cost 55.480
# Epoch : 55 | Batch 350/600 | Cost 57.196
# Epoch : 55 | Batch 400/600 | Cost 30.286
# Epoch : 55 | Batch 450/600 | Cost 37.613
# Epoch : 55 | Batch 500/600 | Cost 74.025
# Epoch : 55 | Batch 550/600 | Cost 60.346
# Epoch: 55/100 | Train cost: 57.05
# Time elapsed: 28.771686200300852
# Epoch : 56 | Batch 0/600 | Cost 60.886
# Epoch : 56 | Batch 50/600 | Cost 54.220
# Epoch : 56 | Batch 100/600 | Cost 63.991
# Epoch : 56 | Batch 150/600 | Cost 44.540
# Epoch : 56 | Batch 200/600 | Cost 56.064
# Epoch : 56 | Batch 250/600 | Cost 38.805
# Epoch : 56 | Batch 300/600 | Cost 54.969
# Epoch : 56 | Batch 350/600 | Cost 68.994
# Epoch : 56 | Batch 400/600 | Cost 54.099
# Epoch : 56 | Batch 450/600 | Cost 69.683
# Epoch : 56 | Batch 500/600 | Cost 54.923
# Epoch : 56 | Batch 550/600 | Cost 33.265
# Epoch: 56/100 | Train cost: 66.53
# Time elapsed: 29.359733633200328
# Epoch : 57 | Batch 0/600 | Cost 74.769
# Epoch : 57 | Batch 50/600 | Cost 62.928
# Epoch : 57 | Batch 100/600 | Cost 58.803
# Epoch : 57 | Batch 150/600 | Cost 65.467
# Epoch : 57 | Batch 200/600 | Cost 58.067
# Epoch : 57 | Batch 250/600 | Cost 69.161
# Epoch : 57 | Batch 300/600 | Cost 51.948
# Epoch : 57 | Batch 350/600 | Cost 57.857
# Epoch : 57 | Batch 400/600 | Cost 68.642
# Epoch : 57 | Batch 450/600 | Cost 53.292
# Epoch : 57 | Batch 500/600 | Cost 67.031
# Epoch : 57 | Batch 550/600 | Cost 62.887
# Epoch: 57/100 | Train cost: 62.08
# Time elapsed: 30.037108147144316
# Epoch : 58 | Batch 0/600 | Cost 59.947
# Epoch : 58 | Batch 50/600 | Cost 74.559
# Epoch : 58 | Batch 100/600 | Cost 64.201
# Epoch : 58 | Batch 150/600 | Cost 42.850
# Epoch : 58 | Batch 200/600 | Cost 54.867
# Epoch : 58 | Batch 250/600 | Cost 55.880
# Epoch : 58 | Batch 300/600 | Cost 73.472
# Epoch : 58 | Batch 350/600 | Cost 72.174
# Epoch : 58 | Batch 400/600 | Cost 69.237
# Epoch : 58 | Batch 450/600 | Cost 51.030
# Epoch : 58 | Batch 500/600 | Cost 66.667
# Epoch : 58 | Batch 550/600 | Cost 71.008
# Epoch: 58/100 | Train cost: 65.33
# Time elapsed: 30.855576848983766
# Epoch : 59 | Batch 0/600 | Cost 68.549
# Epoch : 59 | Batch 50/600 | Cost 76.621
# Epoch : 59 | Batch 100/600 | Cost 43.210
# Epoch : 59 | Batch 150/600 | Cost 72.833
# Epoch : 59 | Batch 200/600 | Cost 73.082
# Epoch : 59 | Batch 250/600 | Cost 54.635
# Epoch : 59 | Batch 300/600 | Cost 87.811
# Epoch : 59 | Batch 350/600 | Cost 43.885
# Epoch : 59 | Batch 400/600 | Cost 82.900
# Epoch : 59 | Batch 450/600 | Cost 51.717
# Epoch : 59 | Batch 500/600 | Cost 63.537
# Epoch : 59 | Batch 550/600 | Cost 76.753
# Epoch: 59/100 | Train cost: 63.96
# Time elapsed: 31.35293678045273
# Epoch : 60 | Batch 0/600 | Cost 67.877
# Epoch : 60 | Batch 50/600 | Cost 67.161
# Epoch : 60 | Batch 100/600 | Cost 65.687
# Epoch : 60 | Batch 150/600 | Cost 80.382
# Epoch : 60 | Batch 200/600 | Cost 32.853
# Epoch : 60 | Batch 250/600 | Cost 68.700
# Epoch : 60 | Batch 300/600 | Cost 55.935
# Epoch : 60 | Batch 350/600 | Cost 43.072
# Epoch : 60 | Batch 400/600 | Cost 59.948
# Epoch : 60 | Batch 450/600 | Cost 78.075
# Epoch : 60 | Batch 500/600 | Cost 48.220
# Epoch : 60 | Batch 550/600 | Cost 65.390
# Epoch: 60/100 | Train cost: 75.61
# Time elapsed: 31.724861669540406
# Epoch : 61 | Batch 0/600 | Cost 80.002
# Epoch : 61 | Batch 50/600 | Cost 34.703
# Epoch : 61 | Batch 100/600 | Cost 84.001
# Epoch : 61 | Batch 150/600 | Cost 32.689
# Epoch : 61 | Batch 200/600 | Cost 63.534
# Epoch : 61 | Batch 250/600 | Cost 42.876
# Epoch : 61 | Batch 300/600 | Cost 68.347
# Epoch : 61 | Batch 350/600 | Cost 35.939
# Epoch : 61 | Batch 400/600 | Cost 68.260
# Epoch : 61 | Batch 450/600 | Cost 74.874
# Epoch : 61 | Batch 500/600 | Cost 49.738
# Epoch : 61 | Batch 550/600 | Cost 58.699
# Epoch: 61/100 | Train cost: 40.13
# Time elapsed: 32.060098600387576
# Epoch : 62 | Batch 0/600 | Cost 32.245
# Epoch : 62 | Batch 50/600 | Cost 47.529
# Epoch : 62 | Batch 100/600 | Cost 63.396
# Epoch : 62 | Batch 150/600 | Cost 76.467
# Epoch : 62 | Batch 200/600 | Cost 57.345
# Epoch : 62 | Batch 250/600 | Cost 73.314
# Epoch : 62 | Batch 300/600 | Cost 70.501
# Epoch : 62 | Batch 350/600 | Cost 67.495
# Epoch : 62 | Batch 400/600 | Cost 83.215
# Epoch : 62 | Batch 450/600 | Cost 42.946
# Epoch : 62 | Batch 500/600 | Cost 201.167
# Epoch : 62 | Batch 550/600 | Cost 85.772
# Epoch: 62/100 | Train cost: 68.83
# Time elapsed: 32.372815601030986
# Epoch : 63 | Batch 0/600 | Cost 68.125
# Epoch : 63 | Batch 50/600 | Cost 55.409
# Epoch : 63 | Batch 100/600 | Cost 52.751
# Epoch : 63 | Batch 150/600 | Cost 44.604
# Epoch : 63 | Batch 200/600 | Cost 83.781
# Epoch : 63 | Batch 250/600 | Cost 45.855
# Epoch : 63 | Batch 300/600 | Cost 67.645
# Epoch : 63 | Batch 350/600 | Cost 46.705
# Epoch : 63 | Batch 400/600 | Cost 44.360
# Epoch : 63 | Batch 450/600 | Cost 56.085
# Epoch : 63 | Batch 500/600 | Cost 65.755
# Epoch : 63 | Batch 550/600 | Cost 40.920
# Epoch: 63/100 | Train cost: 53.48
# Time elapsed: 32.68381839990616
# Epoch : 64 | Batch 0/600 | Cost 65.321
# Epoch : 64 | Batch 50/600 | Cost 66.097
# Epoch : 64 | Batch 100/600 | Cost 43.519
# Epoch : 64 | Batch 150/600 | Cost 83.505
# Epoch : 64 | Batch 200/600 | Cost 46.870
# Epoch : 64 | Batch 250/600 | Cost 51.631
# Epoch : 64 | Batch 300/600 | Cost 71.427
# Epoch : 64 | Batch 350/600 | Cost 101.518
# Epoch : 64 | Batch 400/600 | Cost 46.166
# Epoch : 64 | Batch 450/600 | Cost 77.093
# Epoch : 64 | Batch 500/600 | Cost 63.608
# Epoch : 64 | Batch 550/600 | Cost 67.226
# Epoch: 64/100 | Train cost: 59.66
# Time elapsed: 32.999203232924145
# Epoch : 65 | Batch 0/600 | Cost 55.979
# Epoch : 65 | Batch 50/600 | Cost 76.158
# Epoch : 65 | Batch 100/600 | Cost 53.715
# Epoch : 65 | Batch 150/600 | Cost 65.602
# Epoch : 65 | Batch 200/600 | Cost 75.033
# Epoch : 65 | Batch 250/600 | Cost 70.842
# Epoch : 65 | Batch 300/600 | Cost 74.591
# Epoch : 65 | Batch 350/600 | Cost 105.734
# Epoch : 65 | Batch 400/600 | Cost 58.151
# Epoch : 65 | Batch 450/600 | Cost 61.661
# Epoch : 65 | Batch 500/600 | Cost 93.799
# Epoch : 65 | Batch 550/600 | Cost 31.437
# Epoch: 65/100 | Train cost: 89.94
# Time elapsed: 33.33707625071208
# Epoch : 66 | Batch 0/600 | Cost 104.335
# Epoch : 66 | Batch 50/600 | Cost 71.125
# Epoch : 66 | Batch 100/600 | Cost 62.883
# Epoch : 66 | Batch 150/600 | Cost 93.422
# Epoch : 66 | Batch 200/600 | Cost 89.776
# Epoch : 66 | Batch 250/600 | Cost 62.479
# Epoch : 66 | Batch 300/600 | Cost 89.427
# Epoch : 66 | Batch 350/600 | Cost 74.989
# Epoch : 66 | Batch 400/600 | Cost 70.343
# Epoch : 66 | Batch 450/600 | Cost 89.349
# Epoch : 66 | Batch 500/600 | Cost 110.973
# Epoch : 66 | Batch 550/600 | Cost 79.098
# Epoch: 66/100 | Train cost: 60.40
# Time elapsed: 33.6898379166921
# Epoch : 67 | Batch 0/600 | Cost 63.728
# Epoch : 67 | Batch 50/600 | Cost 89.308
# Epoch : 67 | Batch 100/600 | Cost 113.364
# Epoch : 67 | Batch 150/600 | Cost 49.925
# Epoch : 67 | Batch 200/600 | Cost 99.219
# Epoch : 67 | Batch 250/600 | Cost 75.454
# Epoch : 67 | Batch 300/600 | Cost 79.571
# Epoch : 67 | Batch 350/600 | Cost 82.833
# Epoch : 67 | Batch 400/600 | Cost 132.980
# Epoch : 67 | Batch 450/600 | Cost 75.585
# Epoch : 67 | Batch 500/600 | Cost 65.594
# Epoch : 67 | Batch 550/600 | Cost 123.524
# Epoch: 67/100 | Train cost: 78.92
# Time elapsed: 34.04054104884465
# Epoch : 68 | Batch 0/600 | Cost 73.220
# Epoch : 68 | Batch 50/600 | Cost 90.909
# Epoch : 68 | Batch 100/600 | Cost 88.538
# Epoch : 68 | Batch 150/600 | Cost 76.752
# Epoch : 68 | Batch 200/600 | Cost 71.559
# Epoch : 68 | Batch 250/600 | Cost 73.882
# Epoch : 68 | Batch 300/600 | Cost 50.025
# Epoch : 68 | Batch 350/600 | Cost 57.297
# Epoch : 68 | Batch 400/600 | Cost 91.503
# Epoch : 68 | Batch 450/600 | Cost 62.674
# Epoch : 68 | Batch 500/600 | Cost 82.951
# Epoch : 68 | Batch 550/600 | Cost 95.319
# Epoch: 68/100 | Train cost: 98.23
# Time elapsed: 34.39679184754689
# Epoch : 69 | Batch 0/600 | Cost 89.713
# Epoch : 69 | Batch 50/600 | Cost 41.845
# Epoch : 69 | Batch 100/600 | Cost 92.266
# Epoch : 69 | Batch 150/600 | Cost 79.061
# Epoch : 69 | Batch 200/600 | Cost 89.368
# Epoch : 69 | Batch 250/600 | Cost 232.169
# Epoch : 69 | Batch 300/600 | Cost 58.840
# Epoch : 69 | Batch 350/600 | Cost 54.138
# Epoch : 69 | Batch 400/600 | Cost 79.802
# Epoch : 69 | Batch 450/600 | Cost 91.966
# Epoch : 69 | Batch 500/600 | Cost 100.923
# Epoch : 69 | Batch 550/600 | Cost 34.647
# Epoch: 69/100 | Train cost: 100.13
# Time elapsed: 34.77068990071614
# Epoch : 70 | Batch 0/600 | Cost 87.737
# Epoch : 70 | Batch 50/600 | Cost 78.536
# Epoch : 70 | Batch 100/600 | Cost 87.321
# Epoch : 70 | Batch 150/600 | Cost 105.410
# Epoch : 70 | Batch 200/600 | Cost 60.631
# Epoch : 70 | Batch 250/600 | Cost 70.518
# Epoch : 70 | Batch 300/600 | Cost 91.009
# Epoch : 70 | Batch 350/600 | Cost 96.694
# Epoch : 70 | Batch 400/600 | Cost 83.795
# Epoch : 70 | Batch 450/600 | Cost 83.240
# Epoch : 70 | Batch 500/600 | Cost 90.494
# Epoch : 70 | Batch 550/600 | Cost 72.660
# Epoch: 70/100 | Train cost: 93.55
# Time elapsed: 35.12454090118408
# Epoch : 71 | Batch 0/600 | Cost 98.415
# Epoch : 71 | Batch 50/600 | Cost 47.811
# Epoch : 71 | Batch 100/600 | Cost 57.551
# Epoch : 71 | Batch 150/600 | Cost 85.373
# Epoch : 71 | Batch 200/600 | Cost 47.800
# Epoch : 71 | Batch 250/600 | Cost 78.862
# Epoch : 71 | Batch 300/600 | Cost 55.934
# Epoch : 71 | Batch 350/600 | Cost 77.905
# Epoch : 71 | Batch 400/600 | Cost 68.806
# Epoch : 71 | Batch 450/600 | Cost 66.867
# Epoch : 71 | Batch 500/600 | Cost 103.126
# Epoch : 71 | Batch 550/600 | Cost 108.805
# Epoch: 71/100 | Train cost: 77.38
# Time elapsed: 35.460647817452745
# Epoch : 72 | Batch 0/600 | Cost 60.694
# Epoch : 72 | Batch 50/600 | Cost 78.612
# Epoch : 72 | Batch 100/600 | Cost 76.831
# Epoch : 72 | Batch 150/600 | Cost 71.584
# Epoch : 72 | Batch 200/600 | Cost 46.430
# Epoch : 72 | Batch 250/600 | Cost 69.785
# Epoch : 72 | Batch 300/600 | Cost 69.134
# Epoch : 72 | Batch 350/600 | Cost 56.693
# Epoch : 72 | Batch 400/600 | Cost 72.133
# Epoch : 72 | Batch 450/600 | Cost 99.475
# Epoch : 72 | Batch 500/600 | Cost 47.274
# Epoch : 72 | Batch 550/600 | Cost 114.072
# Epoch: 72/100 | Train cost: 76.45
# Time elapsed: 35.81025931835175
# Epoch : 73 | Batch 0/600 | Cost 58.302
# Epoch : 73 | Batch 50/600 | Cost 73.447
# Epoch : 73 | Batch 100/600 | Cost 86.012
# Epoch : 73 | Batch 150/600 | Cost 87.590
# Epoch : 73 | Batch 200/600 | Cost 70.881
# Epoch : 73 | Batch 250/600 | Cost 73.328
# Epoch : 73 | Batch 300/600 | Cost 57.495
# Epoch : 73 | Batch 350/600 | Cost 72.031
# Epoch : 73 | Batch 400/600 | Cost 60.411
# Epoch : 73 | Batch 450/600 | Cost 93.430
# Epoch : 73 | Batch 500/600 | Cost 79.047
# Epoch : 73 | Batch 550/600 | Cost 42.188
# Epoch: 73/100 | Train cost: 85.26
# Time elapsed: 36.17109481493632
# Epoch : 74 | Batch 0/600 | Cost 64.597
# Epoch : 74 | Batch 50/600 | Cost 65.678
# Epoch : 74 | Batch 100/600 | Cost 72.697
# Epoch : 74 | Batch 150/600 | Cost 91.492
# Epoch : 74 | Batch 200/600 | Cost 68.309
# Epoch : 74 | Batch 250/600 | Cost 43.832
# Epoch : 74 | Batch 300/600 | Cost 87.330
# Epoch : 74 | Batch 350/600 | Cost 250.459
# Epoch : 74 | Batch 400/600 | Cost 94.778
# Epoch : 74 | Batch 450/600 | Cost 56.667
# Epoch : 74 | Batch 500/600 | Cost 55.621
# Epoch : 74 | Batch 550/600 | Cost 93.829
# Epoch: 74/100 | Train cost: 71.63
# Time elapsed: 36.54111771583557
# Epoch : 75 | Batch 0/600 | Cost 61.788
# Epoch : 75 | Batch 50/600 | Cost 66.376
# Epoch : 75 | Batch 100/600 | Cost 88.468
# Epoch : 75 | Batch 150/600 | Cost 94.652
# Epoch : 75 | Batch 200/600 | Cost 37.941
# Epoch : 75 | Batch 250/600 | Cost 57.827
# Epoch : 75 | Batch 300/600 | Cost 53.521
# Epoch : 75 | Batch 350/600 | Cost 79.100
# Epoch : 75 | Batch 400/600 | Cost 70.038
# Epoch : 75 | Batch 450/600 | Cost 76.533
# Epoch : 75 | Batch 500/600 | Cost 70.466
# Epoch : 75 | Batch 550/600 | Cost 67.699
# Epoch: 75/100 | Train cost: 74.61
# Time elapsed: 36.888406066099805
# Epoch : 76 | Batch 0/600 | Cost 66.017
# Epoch : 76 | Batch 50/600 | Cost 69.282
# Epoch : 76 | Batch 100/600 | Cost 85.907
# Epoch : 76 | Batch 150/600 | Cost 53.194
# Epoch : 76 | Batch 200/600 | Cost 78.872
# Epoch : 76 | Batch 250/600 | Cost 57.250
# Epoch : 76 | Batch 300/600 | Cost 40.214
# Epoch : 76 | Batch 350/600 | Cost 61.971
# Epoch : 76 | Batch 400/600 | Cost 84.413
# Epoch : 76 | Batch 450/600 | Cost 70.614
# Epoch : 76 | Batch 500/600 | Cost 64.208
# Epoch : 76 | Batch 550/600 | Cost 41.833
# Epoch: 76/100 | Train cost: 75.48
# Time elapsed: 37.20445956389109
# Epoch : 77 | Batch 0/600 | Cost 56.653
# Epoch : 77 | Batch 50/600 | Cost 70.757
# Epoch : 77 | Batch 100/600 | Cost 76.467
# Epoch : 77 | Batch 150/600 | Cost 57.828
# Epoch : 77 | Batch 200/600 | Cost 79.860
# Epoch : 77 | Batch 250/600 | Cost 48.212
# Epoch : 77 | Batch 300/600 | Cost 69.536
# Epoch : 77 | Batch 350/600 | Cost 64.505
# Epoch : 77 | Batch 400/600 | Cost 76.178
# Epoch : 77 | Batch 450/600 | Cost 59.627
# Epoch : 77 | Batch 500/600 | Cost 50.380
# Epoch : 77 | Batch 550/600 | Cost 73.926
# Epoch: 77/100 | Train cost: 88.17
# Time elapsed: 37.51871528228124
# Epoch : 78 | Batch 0/600 | Cost 71.529
# Epoch : 78 | Batch 50/600 | Cost 57.975
# Epoch : 78 | Batch 100/600 | Cost 50.930
# Epoch : 78 | Batch 150/600 | Cost 64.867
# Epoch : 78 | Batch 200/600 | Cost 65.721
# Epoch : 78 | Batch 250/600 | Cost 65.076
# Epoch : 78 | Batch 300/600 | Cost 44.172
# Epoch : 78 | Batch 350/600 | Cost 71.526
# Epoch : 78 | Batch 400/600 | Cost 61.248
# Epoch : 78 | Batch 450/600 | Cost 73.489
# Epoch : 78 | Batch 500/600 | Cost 53.573
# Epoch : 78 | Batch 550/600 | Cost 60.438
# Epoch: 78/100 | Train cost: 70.05
# Time elapsed: 37.832172314325966
# Epoch : 79 | Batch 0/600 | Cost 99.975
# Epoch : 79 | Batch 50/600 | Cost 68.256
# Epoch : 79 | Batch 100/600 | Cost 63.370
# Epoch : 79 | Batch 150/600 | Cost 52.319
# Epoch : 79 | Batch 200/600 | Cost 62.028
# Epoch : 79 | Batch 250/600 | Cost 87.149
# Epoch : 79 | Batch 300/600 | Cost 62.566
# Epoch : 79 | Batch 350/600 | Cost 78.778
# Epoch : 79 | Batch 400/600 | Cost 57.890
# Epoch : 79 | Batch 450/600 | Cost 59.433
# Epoch : 79 | Batch 500/600 | Cost 88.051
# Epoch : 79 | Batch 550/600 | Cost 121.379
# Epoch: 79/100 | Train cost: 78.10
# Time elapsed: 38.15190634727478
# Epoch : 80 | Batch 0/600 | Cost 56.262
# Epoch : 80 | Batch 50/600 | Cost 203.666
# Epoch : 80 | Batch 100/600 | Cost 120.830
# Epoch : 80 | Batch 150/600 | Cost 145.356
# Epoch : 80 | Batch 200/600 | Cost 71.583
# Epoch : 80 | Batch 250/600 | Cost 73.786
# Epoch : 80 | Batch 300/600 | Cost 66.216
# Epoch : 80 | Batch 350/600 | Cost 67.293
# Epoch : 80 | Batch 400/600 | Cost 63.433
# Epoch : 80 | Batch 450/600 | Cost 83.007
# Epoch : 80 | Batch 500/600 | Cost 50.791
# Epoch : 80 | Batch 550/600 | Cost 73.693
# Epoch: 80/100 | Train cost: 79.55
# Time elapsed: 38.482284315427144
# Epoch : 81 | Batch 0/600 | Cost 61.559
# Epoch : 81 | Batch 50/600 | Cost 76.574
# Epoch : 81 | Batch 100/600 | Cost 124.354
# Epoch : 81 | Batch 150/600 | Cost 75.335
# Epoch : 81 | Batch 200/600 | Cost 42.476
# Epoch : 81 | Batch 250/600 | Cost 88.337
# Epoch : 81 | Batch 300/600 | Cost 87.835
# Epoch : 81 | Batch 350/600 | Cost 79.470
# Epoch : 81 | Batch 400/600 | Cost 65.563
# Epoch : 81 | Batch 450/600 | Cost 73.625
# Epoch : 81 | Batch 500/600 | Cost 202.797
# Epoch : 81 | Batch 550/600 | Cost 182.988
# Epoch: 81/100 | Train cost: 87.10
# Time elapsed: 38.813510751724245
# Epoch : 82 | Batch 0/600 | Cost 63.220
# Epoch : 82 | Batch 50/600 | Cost 113.708
# Epoch : 82 | Batch 100/600 | Cost 74.893
# Epoch : 82 | Batch 150/600 | Cost 89.829
# Epoch : 82 | Batch 200/600 | Cost 61.953
# Epoch : 82 | Batch 250/600 | Cost 80.381
# Epoch : 82 | Batch 300/600 | Cost 73.394
# Epoch : 82 | Batch 350/600 | Cost 90.977
# Epoch : 82 | Batch 400/600 | Cost 62.752
# Epoch : 82 | Batch 450/600 | Cost 65.369
# Epoch : 82 | Batch 500/600 | Cost 162.252
# Epoch : 82 | Batch 550/600 | Cost 66.635
# Epoch: 82/100 | Train cost: 90.02
# Time elapsed: 39.146085345745085
# Epoch : 83 | Batch 0/600 | Cost 119.915
# Epoch : 83 | Batch 50/600 | Cost 71.082
# Epoch : 83 | Batch 100/600 | Cost 214.619
# Epoch : 83 | Batch 150/600 | Cost 92.982
# Epoch : 83 | Batch 200/600 | Cost 60.909
# Epoch : 83 | Batch 250/600 | Cost 33.317
# Epoch : 83 | Batch 300/600 | Cost 108.908
# Epoch : 83 | Batch 350/600 | Cost 50.280
# Epoch : 83 | Batch 400/600 | Cost 73.571
# Epoch : 83 | Batch 450/600 | Cost 103.969
# Epoch : 83 | Batch 500/600 | Cost 79.789
# Epoch : 83 | Batch 550/600 | Cost 81.835
# Epoch: 83/100 | Train cost: 108.27
# Time elapsed: 39.47737801472346
# Epoch : 84 | Batch 0/600 | Cost 85.318
# Epoch : 84 | Batch 50/600 | Cost 70.557
# Epoch : 84 | Batch 100/600 | Cost 99.787
# Epoch : 84 | Batch 150/600 | Cost 45.143
# Epoch : 84 | Batch 200/600 | Cost 183.183
# Epoch : 84 | Batch 250/600 | Cost 90.085
# Epoch : 84 | Batch 300/600 | Cost 74.923
# Epoch : 84 | Batch 350/600 | Cost 72.885
# Epoch : 84 | Batch 400/600 | Cost 102.066
# Epoch : 84 | Batch 450/600 | Cost 55.859
# Epoch : 84 | Batch 500/600 | Cost 100.025
# Epoch : 84 | Batch 550/600 | Cost 73.737
# Epoch: 84/100 | Train cost: 118.14
# Time elapsed: 39.80847599903743
# Epoch : 85 | Batch 0/600 | Cost 96.005
# Epoch : 85 | Batch 50/600 | Cost 261.111
# Epoch : 85 | Batch 100/600 | Cost 73.630
# Epoch : 85 | Batch 150/600 | Cost 56.075
# Epoch : 85 | Batch 200/600 | Cost 102.159
# Epoch : 85 | Batch 250/600 | Cost 89.271
# Epoch : 85 | Batch 300/600 | Cost 70.687
# Epoch : 85 | Batch 350/600 | Cost 86.701
# Epoch : 85 | Batch 400/600 | Cost 65.927
# Epoch : 85 | Batch 450/600 | Cost 55.071
# Epoch : 85 | Batch 500/600 | Cost 193.986
# Epoch : 85 | Batch 550/600 | Cost 79.605
# Epoch: 85/100 | Train cost: 98.11
# Time elapsed: 40.14015628099442
# Epoch : 86 | Batch 0/600 | Cost 62.495
# Epoch : 86 | Batch 50/600 | Cost 191.484
# Epoch : 86 | Batch 100/600 | Cost 112.854
# Epoch : 86 | Batch 150/600 | Cost 193.066
# Epoch : 86 | Batch 200/600 | Cost 92.222
# Epoch : 86 | Batch 250/600 | Cost 185.342
# Epoch : 86 | Batch 300/600 | Cost 177.830
# Epoch : 86 | Batch 350/600 | Cost 179.073
# Epoch : 86 | Batch 400/600 | Cost 73.990
# Epoch : 86 | Batch 450/600 | Cost 123.325
# Epoch : 86 | Batch 500/600 | Cost 462.353
# Epoch : 86 | Batch 550/600 | Cost 73.507
# Epoch: 86/100 | Train cost: 149.02
# Time elapsed: 40.45757608413696
# Epoch : 87 | Batch 0/600 | Cost 177.304
# Epoch : 87 | Batch 50/600 | Cost 109.167
# Epoch : 87 | Batch 100/600 | Cost 126.759
# Epoch : 87 | Batch 150/600 | Cost 83.043
# Epoch : 87 | Batch 200/600 | Cost 48.020
# Epoch : 87 | Batch 250/600 | Cost 93.037
# Epoch : 87 | Batch 300/600 | Cost 116.559
# Epoch : 87 | Batch 350/600 | Cost 119.386
# Epoch : 87 | Batch 400/600 | Cost 144.215
# Epoch : 87 | Batch 450/600 | Cost 180.752
# Epoch : 87 | Batch 500/600 | Cost 91.560
# Epoch : 87 | Batch 550/600 | Cost 94.564
# Epoch: 87/100 | Train cost: 110.67
# Time elapsed: 40.77193028529485
# Epoch : 88 | Batch 0/600 | Cost 67.950
# Epoch : 88 | Batch 50/600 | Cost 102.602
# Epoch : 88 | Batch 100/600 | Cost 89.708
# Epoch : 88 | Batch 150/600 | Cost 125.378
# Epoch : 88 | Batch 200/600 | Cost 205.605
# Epoch : 88 | Batch 250/600 | Cost 98.436
# Epoch : 88 | Batch 300/600 | Cost 132.634
# Epoch : 88 | Batch 350/600 | Cost 96.789
# Epoch : 88 | Batch 400/600 | Cost 170.564
# Epoch : 88 | Batch 450/600 | Cost 145.152
# Epoch : 88 | Batch 500/600 | Cost 309.027
# Epoch : 88 | Batch 550/600 | Cost 303.347
# Epoch: 88/100 | Train cost: 149.42
# Time elapsed: 41.08688519795736
# Epoch : 89 | Batch 0/600 | Cost 99.152
# Epoch : 89 | Batch 50/600 | Cost 113.889
# Epoch : 89 | Batch 100/600 | Cost 80.027
# Epoch : 89 | Batch 150/600 | Cost 79.704
# Epoch : 89 | Batch 200/600 | Cost 196.478
# Epoch : 89 | Batch 250/600 | Cost 199.075
# Epoch : 89 | Batch 300/600 | Cost 74.416
# Epoch : 89 | Batch 350/600 | Cost 130.062
# Epoch : 89 | Batch 400/600 | Cost 97.114
# Epoch : 89 | Batch 450/600 | Cost 80.970
# Epoch : 89 | Batch 500/600 | Cost 276.666
# Epoch : 89 | Batch 550/600 | Cost 114.164
# Epoch: 89/100 | Train cost: 138.13
# Time elapsed: 41.41204690138499
# Epoch : 90 | Batch 0/600 | Cost 87.311
# Epoch : 90 | Batch 50/600 | Cost 65.606
# Epoch : 90 | Batch 100/600 | Cost 66.075
# Epoch : 90 | Batch 150/600 | Cost 92.823
# Epoch : 90 | Batch 200/600 | Cost 117.346
# Epoch : 90 | Batch 250/600 | Cost 101.558
# Epoch : 90 | Batch 300/600 | Cost 101.716
# Epoch : 90 | Batch 350/600 | Cost 303.338
# Epoch : 90 | Batch 400/600 | Cost 104.188
# Epoch : 90 | Batch 450/600 | Cost 88.648
# Epoch : 90 | Batch 500/600 | Cost 78.231
# Epoch : 90 | Batch 550/600 | Cost 101.747
# Epoch: 90/100 | Train cost: 159.30
# Time elapsed: 41.74441354672114
# Epoch : 91 | Batch 0/600 | Cost 166.971
# Epoch : 91 | Batch 50/600 | Cost 102.703
# Epoch : 91 | Batch 100/600 | Cost 63.641
# Epoch : 91 | Batch 150/600 | Cost 173.078
# Epoch : 91 | Batch 200/600 | Cost 106.018
# Epoch : 91 | Batch 250/600 | Cost 112.092
# Epoch : 91 | Batch 300/600 | Cost 207.389
# Epoch : 91 | Batch 350/600 | Cost 79.830
# Epoch : 91 | Batch 400/600 | Cost 106.044
# Epoch : 91 | Batch 450/600 | Cost 73.773
# Epoch : 91 | Batch 500/600 | Cost 92.747
# Epoch : 91 | Batch 550/600 | Cost 182.210
# Epoch: 91/100 | Train cost: 104.51
# Time elapsed: 42.07833773295085
# Epoch : 92 | Batch 0/600 | Cost 167.771
# Epoch : 92 | Batch 50/600 | Cost 106.667
# Epoch : 92 | Batch 100/600 | Cost 251.144
# Epoch : 92 | Batch 150/600 | Cost 75.213
# Epoch : 92 | Batch 200/600 | Cost 101.486
# Epoch : 92 | Batch 250/600 | Cost 115.449
# Epoch : 92 | Batch 300/600 | Cost 84.730
# Epoch : 92 | Batch 350/600 | Cost 73.325
# Epoch : 92 | Batch 400/600 | Cost 196.363
# Epoch : 92 | Batch 450/600 | Cost 121.788
# Epoch : 92 | Batch 500/600 | Cost 104.374
# Epoch : 92 | Batch 550/600 | Cost 72.062
# Epoch: 92/100 | Train cost: 110.18
# Time elapsed: 42.41238956451416
# Epoch : 93 | Batch 0/600 | Cost 88.448
# Epoch : 93 | Batch 50/600 | Cost 172.230
# Epoch : 93 | Batch 100/600 | Cost 80.317
# Epoch : 93 | Batch 150/600 | Cost 101.793
# Epoch : 93 | Batch 200/600 | Cost 59.795
# Epoch : 93 | Batch 250/600 | Cost 115.199
# Epoch : 93 | Batch 300/600 | Cost 80.933
# Epoch : 93 | Batch 350/600 | Cost 130.658
# Epoch : 93 | Batch 400/600 | Cost 78.610
# Epoch : 93 | Batch 450/600 | Cost 129.816
# Epoch : 93 | Batch 500/600 | Cost 94.103
# Epoch : 93 | Batch 550/600 | Cost 101.745
# Epoch: 93/100 | Train cost: 123.45
# Time elapsed: 42.74525299866994
# Epoch : 94 | Batch 0/600 | Cost 108.389
# Epoch : 94 | Batch 50/600 | Cost 122.272
# Epoch : 94 | Batch 100/600 | Cost 71.551
# Epoch : 94 | Batch 150/600 | Cost 124.085
# Epoch : 94 | Batch 200/600 | Cost 171.524
# Epoch : 94 | Batch 250/600 | Cost 88.164
# Epoch : 94 | Batch 300/600 | Cost 115.448
# Epoch : 94 | Batch 350/600 | Cost 83.212
# Epoch : 94 | Batch 400/600 | Cost 104.295
# Epoch : 94 | Batch 450/600 | Cost 134.327
# Epoch : 94 | Batch 500/600 | Cost 76.912
# Epoch : 94 | Batch 550/600 | Cost 86.145
# Epoch: 94/100 | Train cost: 134.21
# Time elapsed: 43.0609832962354
# Epoch : 95 | Batch 0/600 | Cost 104.291
# Epoch : 95 | Batch 50/600 | Cost 98.312
# Epoch : 95 | Batch 100/600 | Cost 122.768
# Epoch : 95 | Batch 150/600 | Cost 109.015
# Epoch : 95 | Batch 200/600 | Cost 93.584
# Epoch : 95 | Batch 250/600 | Cost 90.641
# Epoch : 95 | Batch 300/600 | Cost 117.484
# Epoch : 95 | Batch 350/600 | Cost 88.287
# Epoch : 95 | Batch 400/600 | Cost 101.658
# Epoch : 95 | Batch 450/600 | Cost 141.030
# Epoch : 95 | Batch 500/600 | Cost 138.176
# Epoch : 95 | Batch 550/600 | Cost 66.605
# Epoch: 95/100 | Train cost: 134.66
# Time elapsed: 43.375319600105286
# Epoch : 96 | Batch 0/600 | Cost 135.640
# Epoch : 96 | Batch 50/600 | Cost 116.994
# Epoch : 96 | Batch 100/600 | Cost 130.568
# Epoch : 96 | Batch 150/600 | Cost 85.661
# Epoch : 96 | Batch 200/600 | Cost 84.906
# Epoch : 96 | Batch 250/600 | Cost 136.464
# Epoch : 96 | Batch 300/600 | Cost 104.475
# Epoch : 96 | Batch 350/600 | Cost 58.942
# Epoch : 96 | Batch 400/600 | Cost 89.540
# Epoch : 96 | Batch 450/600 | Cost 87.542
# Epoch : 96 | Batch 500/600 | Cost 143.130
# Epoch : 96 | Batch 550/600 | Cost 104.394
# Epoch: 96/100 | Train cost: 135.18
# Time elapsed: 43.6888047337532
# Epoch : 97 | Batch 0/600 | Cost 100.281
# Epoch : 97 | Batch 50/600 | Cost 194.889
# Epoch : 97 | Batch 100/600 | Cost 83.804
# Epoch : 97 | Batch 150/600 | Cost 197.732
# Epoch : 97 | Batch 200/600 | Cost 100.568
# Epoch : 97 | Batch 250/600 | Cost 82.767
# Epoch : 97 | Batch 300/600 | Cost 126.179
# Epoch : 97 | Batch 350/600 | Cost 132.419
# Epoch : 97 | Batch 400/600 | Cost 111.817
# Epoch : 97 | Batch 450/600 | Cost 181.624
# Epoch : 97 | Batch 500/600 | Cost 122.771
# Epoch : 97 | Batch 550/600 | Cost 102.720
# Epoch: 97/100 | Train cost: 137.79
# Time elapsed: 44.00541676680247
# Epoch : 98 | Batch 0/600 | Cost 124.220
# Epoch : 98 | Batch 50/600 | Cost 59.429
# Epoch : 98 | Batch 100/600 | Cost 86.304
# Epoch : 98 | Batch 150/600 | Cost 118.680
# Epoch : 98 | Batch 200/600 | Cost 142.505
# Epoch : 98 | Batch 250/600 | Cost 91.228
# Epoch : 98 | Batch 300/600 | Cost 85.876
# Epoch : 98 | Batch 350/600 | Cost 112.146
# Epoch : 98 | Batch 400/600 | Cost 102.716
# Epoch : 98 | Batch 450/600 | Cost 111.127
# Epoch : 98 | Batch 500/600 | Cost 48.701
# Epoch : 98 | Batch 550/600 | Cost 161.482
# Epoch: 98/100 | Train cost: 113.96
# Time elapsed: 44.33132201433182
# Epoch : 99 | Batch 0/600 | Cost 129.191
# Epoch : 99 | Batch 50/600 | Cost 99.519
# Epoch : 99 | Batch 100/600 | Cost 111.853
# Epoch : 99 | Batch 150/600 | Cost 70.528
# Epoch : 99 | Batch 200/600 | Cost 90.841
# Epoch : 99 | Batch 250/600 | Cost 121.898
# Epoch : 99 | Batch 300/600 | Cost 131.970
# Epoch : 99 | Batch 350/600 | Cost 120.972
# Epoch : 99 | Batch 400/600 | Cost 98.157
# Epoch : 99 | Batch 450/600 | Cost 100.225
# Epoch : 99 | Batch 500/600 | Cost 117.268
# Epoch : 99 | Batch 550/600 | Cost 55.714
# Epoch: 99/100 | Train cost: 149.17
# Time elapsed: 44.664277799924214
# Epoch : 100 | Batch 0/600 | Cost 215.443
# Epoch : 100 | Batch 50/600 | Cost 123.913
# Epoch : 100 | Batch 100/600 | Cost 101.977
# Epoch : 100 | Batch 150/600 | Cost 115.828
# Epoch : 100 | Batch 200/600 | Cost 101.450
# Epoch : 100 | Batch 250/600 | Cost 105.357
# Epoch : 100 | Batch 300/600 | Cost 211.300
# Epoch : 100 | Batch 350/600 | Cost 93.453
# Epoch : 100 | Batch 400/600 | Cost 104.752
# Epoch : 100 | Batch 450/600 | Cost 76.514
# Epoch : 100 | Batch 500/600 | Cost 142.584
# Epoch : 100 | Batch 550/600 | Cost 113.193
# Epoch: 100/100 | Train cost: 154.12
# Time elapsed: 44.997011315822604
# Total training time: 44.99701446692149
